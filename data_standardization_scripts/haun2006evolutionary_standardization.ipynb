# %%
import json
import os 

with open('config.json', 'r') as f:
    data = json.load(f)

pathway_gen = os.path.abspath(data["python_files"])
pathway_temp = os.path.abspath(data["publications"])
pathway = os.path.join(pathway_temp, "haun2006evolutionary")
original_data_pathway = os.path.join(pathway, "original_data")

# complete_path_1 = os.path.join(original_data_pathway, "Haun_CurrBiol_2006_TRIALS.sav")
complete_path_1 = os.path.join(original_data_pathway, "haun2006evolutionary_standardized_recode.csv")


out_pathway = os.path.join(pathway, "standardized_data")
if not os.path.exists(out_pathway):
    os.makedirs(out_pathway)

# %%
import pandas as pd
import numpy as np
import pyreadstat

# df = pd.read_spss(complete_path_1, usecols=None, convert_categoricals=True)
# original_data_pathway_out = os.path.join(original_data_pathway, 'file name.csv')
# df.to_csv(original_data_pathway_out, encoding='utf-8-sig', index=False)

# df['study_id']="haun2006evolutionary"
# df.columns = map(str.lower, df.columns)
# df=df.applymap(lambda s: s.lower() if type(s) == str else s)
# df.rename(columns={"sex": "sex_temp",
#     "species":"species_temp",
#     "name":"ape",
#     "group":"group_original"}, inplace=True)

# %%
# df['testday'] = df['testday'].astype(str)
# df[['year','month', 'day']] = df['testday'].str.split('-',expand=True)

# %%
# comp_path_name_errors = os.path.join(pathway_gen, "common_name_errors.csv")

# df_name  = pd.read_csv(comp_path_name_errors)
# df['ape'] = df['ape'].str.rstrip()
# for x,y in zip(df_name['wrong'],df_name['right']):
#     df['ape'].replace(x, y, inplace=True)

# comp_path_ape_info = os.path.join(pathway_gen, "apes_includeindatabase.csv")
# apedf = pd.read_csv(comp_path_ape_info)    
# df= df.merge(apedf,left_on='ape', right_on='name', how='left')

# %%
# df.columns
# df.dropna(subset=['species'], inplace=True)
# df.rename(columns={"ape": "participant",
#                 "resp_p":"response_place",
#                 "resp_f":"response_feature"}, inplace=True)

# %%
# comp_path_birth_dates = os.path.join(pathway_gen, "apes_age_calculations.csv")
# ape_dob = pd.read_csv(comp_path_birth_dates) 

# df= df.merge(ape_dob,left_on='participant', right_on='name', how='left') #insert dob of participants
# df['dodc'] = df['year'].astype(str) + '-' + df['month'].astype(str) + '-' + df['day'].astype(str)
# df['dodc'] = pd.to_datetime(df['dodc'])##convert date of data collection to datetime format
# df['dob'] = pd.to_datetime(df['dob'])##convert date of birth to datetime format

# df['age_in_years'] = (df['dodc'] - df['dob']).dt.days//365 ##caculate and append age in years
# df['age_in_months'] = df['dodc'].dt.to_period('M') - df['dob'].dt.to_period('M')
# df['age_in_months'] = df['age_in_months'].apply(lambda x: x.n)

# %%
# correct_update = [[1, 'correct'],
#                     [0, 'incorrect']]
# for x,y in correct_update:
#     df['correct'].replace(x, y, inplace=True, regex=True)
    
# placement_update = [[1,'left'],
#                     [2, 'center'],
#                     [3, 'right']]
# for x,y in placement_update:
#     df['target'].replace(x, y, inplace=True, regex=True)
#     df['response_place'].replace(x, y, inplace=True, regex=True)
#     df['response_feature'].replace(x, y, inplace=True, regex=True)

# df['order'].replace(" ", "_", inplace=True, regex=True)
# df['switch'].replace(" ", "_", inplace=True, regex=True)

df = pd.read_csv(complete_path_1)
df.columns
# Out:
# Index(['study_id', 'year', 'month', 'day', 'participant', 'age_in_years',
#        'sex', 'species', 'trial', 'family', 'training', 'order', 'strat',
#        'target', 'response_place', 'response_feature', 'hidden_location_1',
#        'hidden_location_2', 'correct_place ', 'correct_feature', 'response ',
#        'correct', 'switch', 'choice', 'fing', 'exclude', 'code_yes_no',
#        'new_response_place', 'new_response_feature', 'ape_choice'],
#       dtype='object')

# %%
haun2006evolutionary_standardized=df[['study_id', 'year', 'month', 'day', 'participant', 'age_in_years',
       'sex', 'species', 'trial', 'family', 'training', 'order', 'strat',
        'hidden_location_1',
       'hidden_location_2', 'correct_place ', 'correct_feature', 'response ',
       'correct', 'switch', 'choice', 'fing', 'exclude']]
##removed 'first4ch', 'filter_$', 'learn1', 'learn2'

# haun2006evolutionary_standardized.at[44, [15, 16]] = ['center','left']
# haun2006evolutionary_standardized.at[399, [ 16,17]] = ['left', 'incorrect']
# haun2006evolutionary_standardized.at[44, ['response_place', 'response_feature']] = ['center','left']
# haun2006evolutionary_standardized.at[399, [ 'response_feature','correct']] = ['left', 'incorrect']

comp_out_path_stand = os.path.join(out_pathway, 'haun2006evolutionary_standardized.csv')
haun2006evolutionary_standardized.to_csv(comp_out_path_stand, encoding='utf-8-sig', index=False)


names =haun2006evolutionary_standardized.columns.tolist()
df = pd.DataFrame(names)
df = df.rename(columns={0: "column_name"})
df["description"] = ""
haun2006evolutionary_glossary=df[["column_name", "description"]]

comp_out_path_glossary = os.path.join(out_pathway, 'haun2006evolutionary_glossary.csv')
haun2006evolutionary_glossary.to_csv(comp_out_path_glossary, encoding='utf-8-sig', index=False)
